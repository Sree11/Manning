# %% [markdown]
# <a href="https://colab.research.google.com/github/Sree11/Manning/blob/master/Manning_Medical_Image_Analysis_Using_Pytorch_Ch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://live-platforms-common-resources.s3-us-west-2.amazonaws.com/lp-datasets/Reinhold-103/preprocessed_data.zip
# Out:
# --2020-03-09 12:31:03--  https://live-platforms-common-resources.s3-us-west-2.amazonaws.com/lp-datasets/Reinhold-103/preprocessed_data.zip
# Resolving live-platforms-common-resources.s3-us-west-2.amazonaws.com (live-platforms-common-resources.s3-us-west-2.amazonaws.com)... 52.218.229.209
# Connecting to live-platforms-common-resources.s3-us-west-2.amazonaws.com (live-platforms-common-resources.s3-us-west-2.amazonaws.com)|52.218.229.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8553561498 (8.0G) [application/zip]
# Saving to: ‘preprocessed_data.zip’
#
# preprocessed_data.z 100%[===================>]   7.97G  42.7MB/s    in 3m 5s
#
# 2020-03-09 12:34:08 (44.2 MB/s) - ‘preprocessed_data.zip’ saved [8553561498/8553561498]

# %%
import nibabel as nib

# %%
# !unzip preprocessed_data.zip
# Out:
# Archive:  preprocessed_data.zip
#    creating: hh/
#    creating: hh/t1/
#   inflating: hh/t1/IXI012-HH-1211-T1_fcm.nii.gz
#   inflating: hh/t1/IXI013-HH-1212-T1_fcm.nii.gz
#   inflating: hh/t1/IXI014-HH-1236-T1_fcm.nii.gz
#   inflating: hh/t1/IXI015-HH-1258-T1_fcm.nii.gz
#   inflating: hh/t1/IXI033-HH-1259-T1_fcm.nii.gz
#   inflating: hh/t1/IXI034-HH-1260-T1_fcm.nii.gz
#   inflating: hh/t1/IXI039-HH-1261-T1_fcm.nii.gz
#   inflating: hh/t1/IXI048-HH-1326-T1_fcm.nii.gz
#   inflating: hh/t1/IXI049-HH-1358-T1_fcm.nii.gz
#   inflating: hh/t1/IXI051-HH-1328-T1_fcm.nii.gz
#   inflating: hh/t1/IXI052-HH-1343-T1_fcm.nii.gz
#   inflating: hh/t1/IXI056-HH-1327-T1_fcm.nii.gz
#   inflating: hh/t1/IXI057-HH-1342-T1_fcm.nii.gz
#   inflating: hh/t1/IXI059-HH-1284-T1_fcm.nii.gz
#   inflating: hh/t1/IXI067-HH-1356-T1_fcm.nii.gz
#   inflating: hh/t1/IXI072-HH-2324-T1_fcm.nii.gz
#   inflating: hh/t1/IXI079-HH-1388-T1_fcm.nii.gz
#   inflating: hh/t1/IXI080-HH-1341-T1_fcm.nii.gz
# ...

# %%
import nibabel as nib
image_t1 = nib.load("hh/t1/IXI012-HH-1211-T1_fcm.nii.gz")
image_t2 = nib.load("hh/t2/IXI012-HH-1211-T2_reg_fcm.nii.gz")
image_t1_data = image_t1.get_fdata()
image_t1_data = image_t2.get_fdata()

# %%
print(image_t1.shape)
print(image_t2.shape)
# Out:
# (240, 240, 180)
# (240, 240, 180)

# %%
import matplotlib.pyplot as plt

plt.imshow(image_t1.get_data()[:,:,50])

# %%
plt.imshow(image_t2.get_data()[:,:,50])
